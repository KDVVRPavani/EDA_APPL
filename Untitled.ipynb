# %% [markdown]
# <a href="https://colab.research.google.com/github/KDVVRPavani/EDA_APPL/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## IMPORTING LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Reading the Dataset titanic_train

# %%
file=pd.read_csv('titanic_train.csv')
file.head(10)
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
# 5            6         0       3  ...   8.4583   NaN         Q
# 6            7         0       1  ...  51.8625   E46         S
# 7            8         0       3  ...  21.0750   NaN         S
# 8            9         1       3  ...  11.1333   NaN         S
# 9           10         1       2  ...  30.0708   NaN         C
#
# [10 rows x 12 columns]

# %% [markdown]
# ## Finding Null values

# %%
file.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name  ...  Ticket   Fare  Cabin  Embarked
# 0          False     False   False  False  ...   False  False   True     False
# 1          False     False   False  False  ...   False  False  False     False
# 2          False     False   False  False  ...   False  False   True     False
# 3          False     False   False  False  ...   False  False  False     False
# 4          False     False   False  False  ...   False  False   True     False
# ..           ...       ...     ...    ...  ...     ...    ...    ...       ...
# 886        False     False   False  False  ...   False  False   True     False
# 887        False     False   False  False  ...   False  False  False     False
# 888        False     False   False  False  ...   False  False   True     False
# 889        False     False   False  False  ...   False  False  False     False
# 890        False     False   False  False  ...   False  False   True     False
#
# [891 rows x 12 columns]

# %% [markdown]
# ## Counting Null Values

# %%
count_of_missing_values=file.isnull().sum()
count_of_missing_values[0:12]
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ## Finding datatype

# %%
file.Age.dtype
# Out:
# dtype('float64')

# %%
file.Fare.dtype
# Out:
# dtype('float64')

# %% [markdown]
# ## Filling Nan Values with other values

# %%
file.Cabin.fillna('No Cabin found')
# Out:
# 0      No Cabin found
# 1                 C85
# 2      No Cabin found
# 3                C123
# 4      No Cabin found
#             ...
# 886    No Cabin found
# 887               B42
# 888    No Cabin found
# 889              C148
# 890    No Cabin found
# Name: Cabin, Length: 891, dtype: object

# %% [markdown]
# ## Replacing

# %%
file.Embarked.replace('S','P')
# Out:
# 0      P
# 1      C
# 2      P
# 3      P
# 4      P
#       ..
# 886    P
# 887    P
# 888    P
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %% [markdown]
# ## Line Plot For Given Data

# %%
plt.figure(figsize=(14,6))
plt.title('Line Plot for Age and Fare')
sns.lineplot(data=file,x='Age',y='Fare')
plt.show()

# %% [markdown]
# ## Bar Plot for given data

# %%
plt.figure(figsize=(14,6))
plt.title('Bar Plot for Survived and Age')
sns.barplot(data=file,y='Survived',x='Age')

# %% [markdown]
# ## Heat Map for given data

# %%
plt.figure(figsize=(14,6))
plt.title('Heat Map for given data')
sns.heatmap(file.isnull())

# %% [markdown]
# ## Distplot for given data

# %%
plt.figure(figsize=(14,6))
sns.distplot(file['Survived'].dropna(),color='blue',bins=10)
plt.title('Displot for given data')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Displot for given data')

# %% [markdown]
# ## Box Plot for given data

# %%
plt.figure(figsize=(14,6))
plt.title('Box Plot for given data')
sns.boxplot(x='Embarked',y='Age',data=file,palette='Dark2_r')

# %% [markdown]
# ## Scatter Plot for given data

# %%
plt.figure(figsize=(14,6))
plt.title('Scatter Plot for given data')
sns.scatterplot(x='Embarked',y='Age',data=file,palette='Dark2_r')

# %% [markdown]
# ## Pair Plot for given data

# %%
plt.figure(figsize=(14,6))
sns.pairplot(file)

# %% [markdown]
# ## Cleaning dataset

# %%
file.drop('Age',axis=1,inplace=True)

# %%
file.head(100)
# Out:
#     PassengerId  Survived  Pclass  ...     Fare    Cabin  Embarked
# 0             1         0       3  ...   7.2500      NaN         S
# 1             2         1       1  ...  71.2833      C85         C
# 2             3         1       3  ...   7.9250      NaN         S
# 3             4         1       1  ...  53.1000     C123         S
# 4             5         0       3  ...   8.0500      NaN         S
# ..          ...       ...     ...  ...      ...      ...       ...
# 95           96         0       3  ...   8.0500      NaN         S
# 96           97         0       1  ...  34.6542       A5         C
# 97           98         1       1  ...  63.3583  D10 D12         C
# 98           99         1       2  ...  23.0000      NaN         S
# 99          100         0       2  ...  26.0000      NaN         S
#
# [100 rows x 11 columns]
